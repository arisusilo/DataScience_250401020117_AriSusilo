# %% [markdown]
# <a href="https://colab.research.google.com/github/arisusilo/data-science-2026/blob/main/Pertemuan1_Ari_Susilo_250401020117.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Nama**     = **Ari Susilo**
#
# **Nim**       = **250401020117**
#
# **Kelas**    = **IF405**

# %%
# SEL 1: Output sederhana
print("Hello, Data Sciencel!")

# SEL 2: Variabel & tipe data
nama     = "Ari Susilo"
angkatan = 2026
print(f"Halo, {nama} angkatan {angkatan}!")

# SEL 3: List & perulangan
tools = ["Python","Colab","Jupyter","GitHub"]
for i, tool in enumerate(tools, 1):
  print(f"  {i}. {tool}")

# SEL 4: Fungsi Python
def perkenalan(nama, prodi, angkatan):
  return f"{nama} | {prodi} | {angkatan}"
print(perkenalan("Ari","Informatika",2026))
# Out:
# Hello, Data Sciencel!
# Halo, Ari Susilo angkatan 2026!
#   1. Python
#   2. Colab
#   3. Jupyter
#   4. GitHub
# Ari | Informatika | 2026

# %% [markdown]
# #**KESIMPULAN**
# #1. Apa yang Dipelajari?
# Pemahaman dasar mengenai Data Science sebagai bidang multidisiplin yang menggabungkan tiga pilar utama: Statistika & Matematika, Ilmu Komputer, dan Domain Knowledge
#
# #2. Temuan Utama
# Paradigma Baru: Data Science diakui sebagai 'the fourth paradigm of science' (paradigma keempat ilmu pengetahuan), di mana data menjadi sumber utama penemuan ilmiah.
#
# #3. Keterbatasan atau Pertanyaan yang Muncul
# *   Dinamika Integrasi Metodologi: Bagaimana mengintegrasikan kerangka CRISP-DM yang dirancang sejak akhir 1990-an secara optimal dengan metodologi Agile development modern agar tetap adaptif terhadap perubahan bisnis yang sangat cepat?
# *   Tantangan Kualitas Data (Veracity): Mengingat penambahan dimensi Veracity (kualitas data) pada fenomena Big Data, apa saja langkah konkret yang paling efektif untuk menangani data yang sangat kotor (noisy) pada fase Data Preparation agar tidak merusak akurasi model?
# *   Keterbatasan Teknis Lokal: Penggunaan Google Colab sangat bergantung pada koneksi internet yang stabil. Bagaimana alternatif bagi mahasiswa atau praktisi yang memiliki keterbatasan akses internet dalam menjalankan komputasi berat?
